# %%
# Import Statements
# %config InlineBackend.figure_format = 'retina'
from helper_functions import *
from scipy.stats import ks_2samp
from subprocess import check_output
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the dataset
stack = pd.read_csv("./developer_survey_2018/survey_results_public.csv")
list(stack.columns)
# Out:
# ['Respondent',
#  'Hobby',
#  'OpenSource',
#  'Country',
#  'Student',
#  'Employment',
#  'FormalEducation',
#  'UndergradMajor',
#  'CompanySize',
#  'DevType',
#  'YearsCoding',
#  'YearsCodingProf',
#  'JobSatisfaction',
#  'CareerSatisfaction',
#  'HopeFiveYears',
#  'JobSearchStatus',
#  'LastNewJob',
#  'AssessJob1',
#  'AssessJob2',
#  'AssessJob3',
#  'AssessJob4',
#  'AssessJob5',
#  'AssessJob6',
#  'AssessJob7',
#  'AssessJob8',
#  'AssessJob9',
#  'AssessJob10',
#  'AssessBenefits1',
#  'AssessBenefits2',
#  'AssessBenefits3',
#  'AssessBenefits4',
#  'AssessBenefits5',
#  'AssessBenefits6',
#  'AssessBenefits7',
#  'AssessBenefits8',
#  'AssessBenefits9',
#  'AssessBenefits10',
#  'AssessBenefits11',
#  'JobContactPriorities1',
#  'JobContactPriorities2',
#  'JobContactPriorities3',
#  'JobContactPriorities4',
#  'JobContactPriorities5',
#  'JobEmailPriorities1',
#  'JobEmailPriorities2',
#  'JobEmailPriorities3',
#  'JobEmailPriorities4',
#  'JobEmailPriorities5',
#  'JobEmailPriorities6',
#  'JobEmailPriorities7',
#  'UpdateCV',
#  'Currency',
#  'Salary',
#  'SalaryType',
#  'ConvertedSalary',
#  'CurrencySymbol',
#  'CommunicationTools',
#  'TimeFullyProductive',
#  'EducationTypes',
#  'SelfTaughtTypes',
#  'TimeAfterBootcamp',
#  'HackathonReasons',
#  'AgreeDisagree1',
#  'AgreeDisagree2',
#  'AgreeDisagree3',
#  'LanguageWorkedWith',
#  'LanguageDesireNextYear',
#  'DatabaseWorkedWith',
#  'DatabaseDesireNextYear',
#  'PlatformWorkedWith',
#  'PlatformDesireNextYear',
#  'FrameworkWorkedWith',
#  'FrameworkDesireNextYear',
#  'IDE',
#  'OperatingSystem',
#  'NumberMonitors',
#  'Methodology',
#  'VersionControl',
#  'CheckInCode',
#  'AdBlocker',
#  'AdBlockerDisable',
#  'AdBlockerReasons',
#  'AdsAgreeDisagree1',
#  'AdsAgreeDisagree2',
#  'AdsAgreeDisagree3',
#  'AdsActions',
#  'AdsPriorities1',
#  'AdsPriorities2',
#  'AdsPriorities3',
#  'AdsPriorities4',
#  'AdsPriorities5',
#  'AdsPriorities6',
#  'AdsPriorities7',
#  'AIDangerous',
#  'AIInteresting',
#  'AIResponsible',
#  'AIFuture',
#  'EthicsChoice',
#  'EthicsReport',
#  'EthicsResponsible',
#  'EthicalImplications',
#  'StackOverflowRecommend',
#  'StackOverflowVisit',
#  'StackOverflowHasAccount',
#  'StackOverflowParticipate',
#  'StackOverflowJobs',
#  'StackOverflowDevStory',
#  'StackOverflowJobsRecommend',
#  'StackOverflowConsiderMember',
#  'HypotheticalTools1',
#  'HypotheticalTools2',
#  'HypotheticalTools3',
#  'HypotheticalTools4',
#  'HypotheticalTools5',
#  'WakeTime',
#  'HoursComputer',
#  'HoursOutside',
#  'SkipMeals',
#  'ErgonomicDevices',
#  'Exercise',
#  'Gender',
#  'SexualOrientation',
#  'EducationParents',
#  'RaceEthnicity',
#  'Age',
#  'Dependents',
#  'MilitaryUS',
#  'SurveyTooLong',
#  'SurveyEasy']

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Feature Selection - We've only kept the columns that we will be using for the analysis and the recommender system and have removed all the other columns.
#
# Categorize values - Assigned numerical values to categorical values.

# %%
kept_columns = ['Respondent', 'Student', 'Hobby', 'Country', 'Employment', 
                'FormalEducation', 'UndergradMajor', 'CompanySize', 'YearsCoding', 'YearsCodingProf', 
                'DevType', 'CareerSatisfaction', 'JobSatisfaction', 'EducationTypes', 'SelfTaughtTypes', 
                'LanguageWorkedWith', 'LanguageDesireNextYear', 'IDE', 'Gender', 'EducationParents', 'RaceEthnicity']

stack = stack[kept_columns]
stack.set_index('Respondent', inplace=True)

# %%
satisfaction_strs = {
    'Extremely satisfied': 7,
    'Moderately satisfied': 6,
    'Slightly satisfied': 5,
    'Neither satisfied nor dissatisfied': 4,
    'Slightly dissatisfied': 3,
    'Moderately dissatisfied' : 2,
    'Extremely dissatisfied' : 1
}
satisfy_key = ['JobSatisfaction', 'CareerSatisfaction']
replacers = [
    (satisfy_key, satisfaction_strs)]
def dict_map(dict_to_use):
    def mapper(val):
        if val in dict_to_use:
            return dict_to_use[val]
        else:
            return np.nan

    return mapper

for keys, strs in replacers:
    stack[keys] = stack[keys].applymap(dict_map(strs))

# %%
stack.head(5)
# Out:
#                    Student Hobby         Country          Employment  \
# Respondent
# 1                       No   Yes           Kenya  Employed part-time
# 3                       No   Yes  United Kingdom  Employed full-time
# 4                       No   Yes   United States  Employed full-time
# 5                       No    No   United States  Employed full-time
# 7           Yes, part-time   Yes    South Africa  Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
#
#                          CompanySize       YearsCoding YearsCodingProf  \
# Respondent
# 1                 20 to 99 employees         3-5 years       3-5 years
# 3           10,000 or more employees  30 or more years     18-20 years
# 4                 20 to 99 employees       24-26 years       6-8 years
# 5               100 to 499 employees       18-20 years     12-14 years
# 7           10,000 or more employees         6-8 years       0-2 years
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
#
#             CareerSatisfaction  JobSatisfaction  \
# Respondent
# 1                          7.0              7.0
# 3                          4.0              2.0
# 4                          6.0              6.0
# 5                          3.0              4.0
# 7                          6.0              5.0
#
#                                                EducationTypes  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 3           Taught yourself a new language, framework, or ...
# 4                                                         NaN
# 5           Completed an industry certification program (e...
# 7           Taken a part-time in-person course in programm...
#
#                                               SelfTaughtTypes  \
# Respondent
# 1           The official documentation and/or standards fo...
# 3           The official documentation and/or standards fo...
# 4                                                         NaN
# 5           The official documentation and/or standards fo...
# 7           The official documentation and/or standards fo...
#
#                                           LanguageWorkedWith  \
# Respondent
# 1                                 JavaScript;Python;HTML;CSS
# 3                               JavaScript;Python;Bash/Shell
# 4                                                        NaN
# 5           C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                         C;C++;Java;Matlab;R;SQL;Bash/Shell
#
#                                       LanguageDesireNextYear  \
# Respondent
# 1                                 JavaScript;Python;HTML;CSS
# 3                                                  Go;Python
# 4                                                        NaN
# 5           C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                       Assembly;C;C++;Matlab;SQL;Bash/Shell
#
#                                                    IDE Gender  \
# Respondent
# 1                        Komodo;Vim;Visual Studio Code   Male
# 3                   IPython / Jupyter;Sublime Text;Vim   Male
# 4                                                  NaN    NaN
# 5                     Visual Studio;Visual Studio Code   Male
# 7           Notepad++;Visual Studio;Visual Studio Code   Male
#
#                                              EducationParents  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                                         NaN
# 5           Some college/university study without earning ...
# 7           Some college/university study without earning ...
#
#                            RaceEthnicity
# Respondent
# 1            Black or of African descent
# 3           White or of European descent
# 4                                    NaN
# 5           White or of European descent
# 7           White or of European descent

# %%
# Split the dataframe into Student Developers and Professional Developers
prof_stack = stack[stack.Student == "No"]
stud_stack = stack[stack.Student.str.contains('Yes') == True]

# %%
survey_ques = pd.read_csv("./developer_survey_2018/survey_results_schema.csv")
survey_ques.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1       Hobby                            Do you code as a hobby?
# 2  OpenSource         Do you contribute to open source projects?
# 3     Country          In which country do you currently reside?
# 4     Student  Are you currently enrolled in a formal, degree...

# %%
stud_stack.head()
# Out:
#                    Student Hobby        Country          Employment  \
# Respondent
# 7           Yes, part-time   Yes   South Africa  Employed full-time
# 21          Yes, full-time    No    Netherlands  Employed full-time
# 26          Yes, full-time    No  United States  Employed part-time
# 29          Yes, full-time   Yes          India  Employed full-time
# 31          Yes, full-time   Yes          Chile  Employed part-time
#
#                                               FormalEducation  \
# Respondent
# 7           Some college/university study without earning ...
# 21          Secondary school (e.g. American high school, G...
# 26                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 29                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 31                   Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 7           Computer science, computer engineering, or sof...
# 21                                                        NaN
# 26          Computer science, computer engineering, or sof...
# 29                                                        NaN
# 31          A business discipline (ex. accounting, finance...
#
#                          CompanySize YearsCoding YearsCodingProf  \
# Respondent
# 7           10,000 or more employees   6-8 years       0-2 years
# 21                20 to 99 employees   0-2 years       0-2 years
# 26          1,000 to 4,999 employees   0-2 years             NaN
# 29          10,000 or more employees   0-2 years       3-5 years
# 31           Fewer than 10 employees   3-5 years             NaN
#
#                                                       DevType  \
# Respondent
# 7           Data or business analyst;Desktop or enterprise...
# 21             Back-end developer;Front-end developer;Student
# 26                                                    Student
# 29          Data or business analyst;Data scientist or mac...
# 31          Back-end developer;Front-end developer;Full-st...
#
#             CareerSatisfaction  JobSatisfaction  \
# Respondent
# 7                          6.0              5.0
# 21                         2.0              4.0
# 26                         NaN              NaN
# 29                         7.0              5.0
# 31                         NaN              NaN
#
#                                                EducationTypes  \
# Respondent
# 7           Taken a part-time in-person course in programm...
# 21          Received on-the-job training in software devel...
# 26                                                        NaN
# 29                        Contributed to open source software
# 31                                                        NaN
#
#                                               SelfTaughtTypes  \
# Respondent
# 7           The official documentation and/or standards fo...
# 21                                                        NaN
# 26                                                        NaN
# 29                                                        NaN
# 31                                                        NaN
#
#                              LanguageWorkedWith  \
# Respondent
# 7            C;C++;Java;Matlab;R;SQL;Bash/Shell
# 21          Java;JavaScript;PHP;VB.NET;HTML;CSS
# 26                                          NaN
# 29                                     C;C++;C#
# 31                                          NaN
#
#                           LanguageDesireNextYear  \
# Respondent
# 7           Assembly;C;C++;Matlab;SQL;Bash/Shell
# 21                                           NaN
# 26                                           NaN
# 29                                      Python;R
# 31                                           NaN
#
#                                                    IDE  Gender  \
# Respondent
# 7           Notepad++;Visual Studio;Visual Studio Code    Male
# 21                             Notepad++;Visual Studio    Male
# 26                                                 NaN     NaN
# 29                           Android Studio;Coda;Xcode  Female
# 31                                                 NaN     NaN
#
#                                              EducationParents  \
# Respondent
# 7           Some college/university study without earning ...
# 21                                           Associate degree
# 26                                                        NaN
# 29          Some college/university study without earning ...
# 31                                                        NaN
#
#                            RaceEthnicity
# Respondent
# 7           White or of European descent
# 21          White or of European descent
# 26                                   NaN
# 29                                   NaN
# 31                                   NaN

# %%
# Selecting only limited features from the above sub data frames and copying important features into 2 new dataframes
important_features_prof = ['Hobby', 'Country', 'FormalEducation', 'UndergradMajor','YearsCoding', 'YearsCodingProf',
                           'DevType', 'CareerSatisfaction', 'JobSatisfaction','LanguageWorkedWith', 
                           'LanguageDesireNextYear']


important_features_stud = ['Hobby', 'Country', 'FormalEducation', 'YearsCoding','LanguageWorkedWith', 
                           'LanguageDesireNextYear']

final_prof_stack = prof_stack[important_features_prof].copy()
final_stud_stack = stud_stack[important_features_stud].copy()

# %%
# Student Developers network
preprocessed_dfs_stud = preprocessed(final_stud_stack, ["LanguageWorkedWith", "LanguageDesireNextYear"],
                                     'LanguageDesireNextYear', False)

# %%
# Professional Developers network
preprocessed_dfs_prof = preprocessed(final_prof_stack, ["LanguageWorkedWith", "LanguageDesireNextYear", 'DevType'],
                                     'LanguageDesireNextYear', True)

# %% [markdown]
# # Predict
#
# In this section, we show an example of a recommendation. Based on the recruiter's requirements - for both students and professionals, it recommends them suitable candidates.

# %% [markdown]
# # Student
#
# These are the requirements of the recruiter based on the questionnaire:
# - Do you code as a Hobby? : **Yes**
# - In which country do you currently reside? : ** United States**
# - Which of the following best describes the highest level of formal education that you’ve completed ? : **Bachelor’s degree (BA, BS, B.Eng., etc.)**
# - Including any education, for how many years have you been coding ? : **3-5 years**
# - Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year? : **C#;Java**
# - Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year? : **C++;Python**

# %%
final_stud_stack.loc[final_stud_stack.shape[0]] = ['Yes', 'United States', 'Bachelor’s degree (BA, BS, B.Eng., etc.)',
                                                   '3-5 years', 'C#;Java', 'C++;Python']
predict_dfs_stud = preprocessed(final_stud_stack, ["LanguageWorkedWith", "LanguageDesireNextYear"],
                                          'LanguageDesireNextYear', False)
knn_stud = compute_knn_graph(predict_dfs_stud[0])

best_predict_stud = np.argsort(knn_stud.toarray()[-1])[::-1][1:6]
size_stud = preprocessed_dfs_stud[1].shape[0]
predict_dfs_stud[1].iloc[[size_stud-1] + list(best_predict_stud), :]
# Out:
#            Hobby        Country  \
# Respondent
# 31110        Yes        Bolivia
# 5284         Yes  United States
# 13363        Yes  United States
# 12534        Yes      Indonesia
# 14341        Yes  United States
# 13655        Yes  United States
#
#                                               FormalEducation YearsCoding  \
# Respondent
# 31110       Some college/university study without earning ...   3-5 years
# 5284                 Bachelor’s degree (BA, BS, B.Eng., etc.)   3-5 years
# 13363                Bachelor’s degree (BA, BS, B.Eng., etc.)   3-5 years
# 12534                Bachelor’s degree (BA, BS, B.Eng., etc.)   3-5 years
# 14341                Bachelor’s degree (BA, BS, B.Eng., etc.)   3-5 years
# 13655                Bachelor’s degree (BA, BS, B.Eng., etc.)   3-5 years
#
#               LanguageWorkedWith LanguageDesireNextYear
# Respondent
# 31110       Delphi/Object Pascal   Delphi/Object Pascal
# 5284                    Assembly               Assembly
# 13363                         Go                     Go
# 12534                       Java             JavaScript
# 14341        JavaScript;HTML;CSS             TypeScript
# 13655                  C#;Python                 C++;F#

# %% [markdown]
# All of these people are the ones recommended through our recommender system and they satisfy a lot of the requirements specified by the user.

# %% [markdown]
# # Professional
#
# These are the requirements of the recruiter based on the questionnaire:
# - Do you code as a Hobby? : **Yes**
# - In which country do you currently reside? : ** United States**
# - Which of the following best describes the highest level of formal education that you’ve completed ? : **Master’s degree (MA, MS, M.Eng., MBA, etc.)**
# - Which of the following best describes your main field of study (aka 'major') in college or university/for your undergraduate studies? : Computer science, computer engineering, or software engineering
# - Including any education, for how many years have you been coding ? : **6-8 years**
# - For how many years have you coded professionally (as a part of your work) ? : **3-5 years**
# - Which of the following describe you ? : **Full-stack developer**
# - How satisfied are you with your current job? If you work more than one job, please answer regarding the one you spend the most hours on. : **8.0**
# - Overall, how satisfied are you with your career thus far ? : **9.0**
# - Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year? : **Java;PHP;Python**
# - Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year? : **Go;Python;Lua**

# %%
important_features_prof = ['Hobby', 'Country', 'FormalEducation', 'UndergradMajor','YearsCoding', 'YearsCodingProf',
                           'DevType', 'CareerSatisfaction', 'JobSatisfaction','LanguageWorkedWith', 
    # Student

These are the requirements of the recruiter based on the questionnaire:
- Do you code as a Hobby? : **Yes**
- In which country do you currently reside? : ** United States**
- Which of the following best describes the highest level of formal education that you’ve completed ? : **Bachelor’s degree (BA, BS, B.Eng., etc.)**
- Including any education, for how many years have you been coding ? : **3-5 years**
- Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year? : **C#;Java**
- Which of the following languages have you done extensive development work in over the past year, and which do you want to work in over the next year? : **C++;Python**                       'LanguageDesireNextYear']

final_prof_stack.loc[final_prof_stack.shape[0]] = ['Yes', 'India', "Master’s degree (MA, MS, M.Eng., MBA, etc.)", 
                                                   'Computer science, computer engineering, or software engineering',
                                                   '6-8 years', '3-5 years', 'Full-stack developer', 
                                                   8.0, 9.0, 'Java;PHP;Python','Go;Python;Lua']

predict_dfs_prof = preprocessed(final_prof_stack, ["LanguageWorkedWith", "LanguageDesireNextYear", "DevType"],
                                          'LanguageDesireNextYear', True)

knn_prof = compute_knn_graph(predict_dfs_prof[0])
best_predict_prof = np.argsort(knn_prof.toarray()[-1])[::-1][1:6]

size_prof = preprocessed_dfs_prof[1].shape[0]
predict_dfs_prof[1].iloc[[size_prof-1] + list(best_predict_prof), :]
# Out:
#            Hobby        Country  \
# Respondent
# 101512       Yes  United States
# 43167        Yes  United States
# 28507        Yes        Germany
# 86867        Yes         Sweden
# 62611        Yes        Denmark
# 29760        Yes          India
#
#                                               FormalEducation  \
# Respondent
# 101512      Some college/university study without earning ...
# 43167                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28507             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 86867             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 62611             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 29760             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 101512      Information systems, information technology, o...
# 43167       Computer science, computer engineering, or sof...
# 28507       Computer science, computer engineering, or sof...
# 86867       Computer science, computer engineering, or sof...
# 62611       Computer science, computer engineering, or sof...
# 29760       Computer science, computer engineering, or sof...
#
#                  YearsCoding   YearsCodingProf  \
# Respondent
# 101512      30 or more years  30 or more years
# 43167            18-20 years       15-17 years
# 28507            18-20 years       15-17 years
# 86867             9-11 years         6-8 years
# 62611            27-29 years       15-17 years
# 29760              0-2 years         0-2 years
#
#                                                       DevType  \
# Respondent
# 101512                                   Full-stack developer
# 43167       Back-end developer;Desktop or enterprise appli...
# 28507       Back-end developer;Front-end developer;Full-st...
# 86867       Back-end developer;Front-end developer;Full-st...
# 62611       Back-end developer;Front-end developer;Full-st...
# 29760       Back-end developer;Data scientist or machine l...
#
#             CareerSatisfaction  JobSatisfaction  \
# Respondent
# 101512                     4.0              2.0
# 43167                      4.0              2.0
# 28507                      6.0              6.0
# 86867                      4.0              4.0
# 62611                      6.0              6.0
# 29760                      2.0              1.0
#
#                                  LanguageWorkedWith  \
# Respondent
# 101512                   C#;JavaScript;SQL;HTML;CSS
# 43167                  Java;JavaScript;SQL;HTML;CSS
# 28507               C#;Java;JavaScript;SQL;HTML;CSS
# 86867                  Java;JavaScript;SQL;HTML;CSS
# 62611       Java;JavaScript;SQL;TypeScript;HTML;CSS
# 29760                  Java;JavaScript;SQL;HTML;CSS
#
#                                 LanguageDesireNextYear
# Respondent
# 101512           C#;JavaScript;SQL;TypeScript;HTML;CSS
# 43167                     Java;JavaScript;SQL;HTML;CSS
# 28507       C#;Java;JavaScript;SQL;TypeScript;HTML;CSS
# 86867                     Java;JavaScript;SQL;HTML;CSS
# 62611          Java;JavaScript;SQL;TypeScript;HTML;CSS
# 29760                     Java;JavaScript;SQL;HTML;CSS

# %% [markdown]
# All of these people are the ones recommended through our recommender system and they satisfy a lot of the requirements specified by the user.
